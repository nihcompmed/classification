# %% [markdown]
# ## Data cleaning
#
# In this section, we first see the data structure and identify data attributes. We then clean the data, including removing bad rows, bad attributes, imputing missing values, etc.
#
# First of all, we import the necessary packages to the Jupyter notebook:

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(1)

# %% [markdown]
# We load the raw data.

# %%
df = pd.read_csv('kidney_disease_data.csv',sep= ',')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %% [markdown]
# We drop the column `id` which is not an attribute.

# %%
df = df.drop('id',axis=1)

# %% [markdown]
# There are 25 attributes: <br/>
# 1) age: Age (yeas) --> numerical<br/>
# 2) bp: Blood Pressure (mm/Hg) --> numerical<br/>
# 3) sg: Specific Gravity (1.005,1.010,1.015,1.020,1.025) --> numerical<br/>
# 4) al: Albumin(0,1,2,3,4,5) --> numerical<br/>
# 5) su: Sugar(0,1,2,3,4,5) --> numerical<br/>
# 6) rbc: Red Blood Cells (normal, abnormal) --> binary <br/>
# 7) pc: Pus Cell (normal, abnormal) --> binary <br/>
# 8) pcc: Pus Cell clumps (present, notpresent) --> binary<br/>
# 9) ba: Bacteria (present, notpresent) --> binary<br/>
# 10) bgr: Blood Glucose Random (mgs/dl) --> numerical<br/>
# 11) bu: Blood Urea (mgs/dl) --> numerical<br/>
# 12) sc: Serum Creatinine (mgs/dl) --> numerical<br/>
# 13) sod: Sodium (mEq/L) --> numerical<br/>
# 14) pot: Potassium (mEq/L) --> numerical<br/>
# 15) hemo: Hemoglobin (gms) --> numerical<br/>
# 16) pcv: Packed Cell Volume --> numerical<br/>
# 17) wc: White Blood Cell Count (cells/cumm) --> numerical<br/>
# 18) rc: Red Blood Cell Count (millions/cmm) --> numerical<br/>
# 19) htn: Hypertension (yes, no) --> binary <br/>
# 20) dm: Diabetes Mellitus (yes, no) --> binary <br/>
# 21) cad: Coronary Artery Disease (yes, no) --> binary<br/>
# 22) appet: Appetite (good, poor) --> binary <br/>
# 23) pe: Pedal Edema (yes, no) --> binary <br/>
# 24) ane: Anemia (yes, no) --> binary <br/>
#
# and 1 class: ckd (chronic kidney disease) and notckd (not chronic kidney disease)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
# age               391 non-null float64
# bp                388 non-null float64
# sg                353 non-null float64
# al                354 non-null float64
# su                351 non-null float64
# rbc               248 non-null object
# pc                335 non-null object
# pcc               396 non-null object
# ba                396 non-null object
# bgr               356 non-null float64
# bu                381 non-null float64
# sc                383 non-null float64
# sod               313 non-null float64
# pot               312 non-null float64
# hemo              348 non-null float64
# pcv               330 non-null object
# wc                295 non-null object
# rc                270 non-null object
# htn               398 non-null object
# dm                398 non-null object
# cad               398 non-null object
# appet             399 non-null object
# pe                399 non-null object
# ane               399 non-null object
# classification    400 non-null object
# dtypes: float64(11), object(14)
# memory usage: 78.2+ KB

# %% [markdown]
# We see that `rbc`, `wc`, `rc`, `sod`, `pot` contain so many missing values, so we will remove these attributes.

# %%
df = df.drop(['rbc', 'wc', 'rc','sod','pot'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 20 columns):
# age               391 non-null float64
# bp                388 non-null float64
# sg                353 non-null float64
# al                354 non-null float64
# su                351 non-null float64
# pc                335 non-null object
# pcc               396 non-null object
# ba                396 non-null object
# bgr               356 non-null float64
# bu                381 non-null float64
# sc                383 non-null float64
# hemo              348 non-null float64
# pcv               330 non-null object
# htn               398 non-null object
# dm                398 non-null object
# cad               398 non-null object
# appet             399 non-null object
# pe                399 non-null object
# ane               399 non-null object
# classification    400 non-null object
# dtypes: float64(9), object(11)
# memory usage: 62.6+ KB

# %% [markdown]
# To clearn the data, we first replace the empty value by `nan`.

# %%
# replace empty by nan
df = df.replace(r'^\s+$', np.nan, regex=True)
df
# Out:
#       age     bp     sg   al   su        pc         pcc          ba    bgr  \
# 0    48.0   80.0  1.020  1.0  0.0    normal  notpresent  notpresent  121.0
# 1     7.0   50.0  1.020  4.0  0.0    normal  notpresent  notpresent    NaN
# 2    62.0   80.0  1.010  2.0  3.0    normal  notpresent  notpresent  423.0
# 3    48.0   70.0  1.005  4.0  0.0  abnormal     present  notpresent  117.0
# 4    51.0   80.0  1.010  2.0  0.0    normal  notpresent  notpresent  106.0
# 5    60.0   90.0  1.015  3.0  0.0       NaN  notpresent  notpresent   74.0
# 6    68.0   70.0  1.010  0.0  0.0    normal  notpresent  notpresent  100.0
# 7    24.0    NaN  1.015  2.0  4.0  abnormal  notpresent  notpresent  410.0
# 8    52.0  100.0  1.015  3.0  0.0  abnormal     present  notpresent  138.0
# 9    53.0   90.0  1.020  2.0  0.0  abnormal     present  notpresent   70.0
# 10   50.0   60.0  1.010  2.0  4.0  abnormal     present  notpresent  490.0
# 11   63.0   70.0  1.010  3.0  0.0  abnormal     present  notpresent  380.0
# 12   68.0   70.0  1.015  3.0  1.0    normal     present  notpresent  208.0
# 13   68.0   70.0    NaN  NaN  NaN       NaN  notpresent  notpresent   98.0
# 14   68.0   80.0  1.010  3.0  2.0  abnormal     present     present  157.0
# 15   40.0   80.0  1.015  3.0  0.0    normal  notpresent  notpresent   76.0
# 16   47.0   70.0  1.015  2.0  0.0    normal  notpresent  notpresent   99.0
# 17   47.0   80.0    NaN  NaN  NaN       NaN  notpresent  notpresent  114.0
# 18   60.0  100.0  1.025  0.0  3.0    normal  notpresent  notpresent  263.0
# 19   62.0   60.0  1.015  1.0  0.0  abnormal     present  notpresent  100.0
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  notpresent  notpresent  173.0
# 21   60.0   90.0    NaN  NaN  NaN       NaN  notpresent  notpresent    NaN
# 22   48.0   80.0  1.025  4.0  0.0  abnormal  notpresent  notpresent   95.0
# 23   21.0   70.0  1.010  0.0  0.0    normal  notpresent  notpresent    NaN
# 24   42.0  100.0  1.015  4.0  0.0  abnormal  notpresent     present    NaN
# 25   61.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent  108.0
# 26   75.0   80.0  1.015  0.0  0.0    normal  notpresent  notpresent  156.0
# 27   69.0   70.0  1.010  3.0  4.0  abnormal  notpresent  notpresent  264.0
# 28   75.0   70.0    NaN  1.0  3.0       NaN  notpresent  notpresent  123.0
# 29   68.0   70.0  1.005  1.0  0.0  abnormal     present  notpresent    NaN
# ..    ...    ...    ...  ...  ...       ...         ...         ...    ...
# 370  69.0   70.0  1.020  0.0  0.0    normal  notpresent  notpresent   83.0
# 371  28.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent   79.0
# 372  72.0   60.0  1.020  0.0  0.0    normal  notpresent  notpresent  109.0
# 373  61.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent  133.0
# 374  79.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  111.0
# 375  70.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent   74.0
# 376  58.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent   88.0
# 377  64.0   70.0  1.020  0.0  0.0    normal  notpresent  notpresent   97.0
# 378  71.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent    NaN
# 379  62.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   78.0
# 380  59.0   60.0  1.020  0.0  0.0    normal  notpresent  notpresent  113.0
# 381  71.0   70.0  1.025  0.0  0.0       NaN  notpresent  notpresent   79.0
# 382  48.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   75.0
# 383  80.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  119.0
# 384  57.0   60.0  1.020  0.0  0.0    normal  notpresent  notpresent  132.0
# 385  63.0   70.0  1.020  0.0  0.0    normal  notpresent  notpresent  113.0
# 386  46.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent  100.0
# 387  15.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   93.0
# 388  51.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent   94.0
# 389  41.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  112.0
# 390  52.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   99.0
# 391  36.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   85.0
# 392  57.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  133.0
# 393  43.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent  117.0
# 394  50.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  137.0
# 395  55.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  140.0
# 396  42.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent   75.0
# 397  12.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  100.0
# 398  17.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent  114.0
# 399  58.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  131.0
#
#         bu    sc  hemo  pcv  htn   dm  cad appet   pe  ane classification
# 0     36.0   1.2  15.4   44  yes  yes   no  good   no   no            ckd
# 1     18.0   0.8  11.3   38   no   no   no  good   no   no            ckd
# 2     53.0   1.8   9.6   31   no  yes   no  poor   no  yes            ckd
# 3     56.0   3.8  11.2   32  yes   no   no  poor  yes  yes            ckd
# 4     26.0   1.4  11.6   35   no   no   no  good   no   no            ckd
# 5     25.0   1.1  12.2   39  yes  yes   no  good  yes   no            ckd
# 6     54.0  24.0  12.4   36   no   no   no  good   no   no            ckd
# 7     31.0   1.1  12.4   44   no  yes   no  good  yes   no            ckd
# 8     60.0   1.9  10.8   33  yes  yes   no  good   no  yes            ckd
# 9    107.0   7.2   9.5   29  yes  yes   no  poor   no  yes            ckd
# 10    55.0   4.0   9.4   28  yes  yes   no  good   no  yes            ckd
# 11    60.0   2.7  10.8   32  yes  yes   no  poor  yes   no            ckd
# 12    72.0   2.1   9.7   28  yes  yes  yes  poor  yes   no            ckd
# 13    86.0   4.6   9.8  NaN  yes  yes  yes  poor  yes   no            ckd
# 14    90.0   4.1   5.6   16  yes  yes  yes  poor  yes   no            ckd
# 15   162.0   9.6   7.6   24  yes   no   no  good   no  yes            ckd
# 16    46.0   2.2  12.6  NaN   no   no   no  good   no   no            ckd
# 17    87.0   5.2  12.1  NaN  yes   no   no  poor   no   no            ckd
# 18    27.0   1.3  12.7   37  yes  yes  yes  good   no   no            ckd
# 19    31.0   1.6  10.3   30  yes   no  yes  good   no   no            ckd
# 20   148.0   3.9   7.7   24  yes  yes  yes  poor  yes  yes            ckd
# 21   180.0  76.0  10.9   32  yes  yes  yes  good   no   no            ckd
# 22   163.0   7.7   9.8   32  yes   no   no  good   no  yes            ckd
# 23     NaN   NaN   NaN  NaN   no   no   no  poor   no  yes            ckd
# 24    50.0   1.4  11.1   39  yes   no   no  poor   no   no            ckd
# 25    75.0   1.9   9.9   29  yes  yes   no  good   no  yes            ckd
# 26    45.0   2.4  11.6   35  yes  yes   no  poor   no   no            ckd
# 27    87.0   2.7  12.5   37  yes  yes  yes  good  yes   no            ckd
# 28    31.0   1.4   NaN  NaN   no  yes   no  good   no   no            ckd
# 29    28.0   1.4  12.9   38   no   no  yes  good   no   no            ckd
# ..     ...   ...   ...  ...  ...  ...  ...   ...  ...  ...            ...
# 370   42.0   1.2  16.2   50   no   no   no  good   no   no         notckd
# 371   50.0   0.5  17.6   51   no   no   no  good   no   no         notckd
# 372   26.0   0.9  15.0   52   no   no   no  good   no   no         notckd
# 373   38.0   1.0  13.7   47   no   no   no  good   no   no         notckd
# 374   44.0   1.2  16.3   40   no   no   no  good   no   no         notckd
# 375   41.0   0.5  15.1   48   no   no   no  good   no   no         notckd
# 376   16.0   1.1  16.4   53   no   no   no  good   no   no         notckd
# 377   27.0   0.7  13.8   49   no   no   no  good   no   no         notckd
# 378    NaN   0.9  15.2   42   no   no   no  good   no   no         notckd
# 379   45.0   0.6  16.1   50   no   no   no  good   no   no         notckd
# 380   23.0   1.1  15.3   54   no   no   no  good   no   no         notckd
# 381   47.0   0.5  16.6   40   no   no   no  good   no   no         notckd
# 382   22.0   0.8  16.8   51   no   no   no  good   no   no         notckd
# 383   46.0   0.7  13.9   49   no   no   no  good   no   no         notckd
# 384   18.0   1.1  15.4   42   no   no   no  good   no   no         notckd
# 385   25.0   0.6  16.5   52   no   no   no  good   no   no         notckd
# 386   47.0   0.5  16.4   43   no   no   no  good   no   no         notckd
# 387   17.0   0.9  16.7   50   no   no   no  good   no   no         notckd
# 388   15.0   1.2  15.5   46   no   no   no  good   no   no         notckd
# 389   48.0   0.7  17.0   52   no   no   no  good   no   no         notckd
# 390   25.0   0.8  15.0   52   no   no   no  good   no   no         notckd
# 391   16.0   1.1  15.6   44   no   no   no  good   no   no         notckd
# 392   48.0   1.2  14.8   46   no   no   no  good   no   no         notckd
# 393   45.0   0.7  13.0   54   no   no   no  good   no   no         notckd
# 394   46.0   0.8  14.1   45   no   no   no  good   no   no         notckd
# 395   49.0   0.5  15.7   47   no   no   no  good   no   no         notckd
# 396   31.0   1.2  16.5   54   no   no   no  good   no   no         notckd
# 397   26.0   0.6  15.8   49   no   no   no  good   no   no         notckd
# 398   50.0   1.0  14.2   51   no   no   no  good   no   no         notckd
# 399   18.0   1.1  15.8   53   no   no   no  good   no   no         notckd
#
# [400 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 20 columns):
# age               391 non-null float64
# bp                388 non-null float64
# sg                353 non-null float64
# al                354 non-null float64
# su                351 non-null float64
# pc                335 non-null object
# pcc               396 non-null object
# ba                396 non-null object
# bgr               356 non-null float64
# bu                381 non-null float64
# sc                383 non-null float64
# hemo              348 non-null float64
# pcv               330 non-null object
# htn               398 non-null object
# dm                398 non-null object
# cad               398 non-null object
# appet             399 non-null object
# pe                399 non-null object
# ane               399 non-null object
# classification    400 non-null object
# dtypes: float64(9), object(11)
# memory usage: 62.6+ KB

# %% [markdown]
# We find bad rows which contain too many missing values, then remove them.

# %%
# find bad rows having too many missing values
n_null = np.array(df.isnull().sum(axis=1))
bad_row = np.array([])
for t in range(len(n_null)):
    if n_null[t] > 4:
        #print(t)
        bad_row = np.append(bad_row,t)
        
print(bad_row)
print(len(bad_row))

# delete bad rows
df = df.drop(bad_row)
df.info()
# Out:
# [ 13.  17.  21.  23.  30.  57.  59.  82.  86. 104. 109. 113. 122. 125.
#  132. 142. 148. 161. 165. 166. 188. 197. 203. 215. 222. 228. 232. 268.]
# 28
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 0 to 399
# Data columns (total 20 columns):
# age               366 non-null float64
# bp                364 non-null float64
# sg                347 non-null float64
# al                348 non-null float64
# su                345 non-null float64
# pc                330 non-null object
# pcc               368 non-null object
# ba                368 non-null object
# bgr               338 non-null float64
# bu                359 non-null float64
# sc                361 non-null float64
# hemo              336 non-null float64
# pcv               325 non-null object
# htn               370 non-null object
# dm                370 non-null object
# cad               370 non-null object
# appet             371 non-null object
# pe                371 non-null object
# ane               371 non-null object
# classification    372 non-null object
# dtypes: float64(9), object(11)
# memory usage: 61.0+ KB

# %% [markdown]
# The data still contain errors, such as `\t`, ` `, `\?`. We will delete `\t` and ` ` and convert `\?` to `np.nan`.

# %%
df = df.replace('\t','',regex=True)
df = df.replace(' ','',regex=True)
df = df.replace('\?','np.nan',regex=True)

# %% [markdown]
# The current type of variable 'pcv' is object, we will convert them to numeric variable.

# %%
print(np.dtype(df['pcv']))

df["pcv"] = pd.to_numeric(df.pcv, errors='coerce')
# Out:
# object

# %% [markdown]
# For convenience, we separate independents `X` and dependent `y` from the data.

# %%
X = df.drop('classification',axis=1)
y = df['classification']

# %% [markdown]
# We impute the missing value of X at each column by its median value.

# %%
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):
    def __init__(self):
        """Impute missing values.
        - Columns of dtype object are imputed with the most frequent value in column.
        - Columns of other types are imputed with mean of column.
        """
    def fit(self, X, y=None):
        self.fill = pd.Series([X[c].value_counts().index[0]
            # numerical --> mean, categorical --> median
            #if X[c].dtype == np.dtype('O') else X[c].mean() for c in X], index=X.columns)  
                               
            # numerical, categorical --> median                   
            if X[c].dtype == np.dtype('O') else X[c].median() for c in X], index=X.columns)
        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
X = DataFrameImputer().fit_transform(X)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 0 to 399
# Data columns (total 19 columns):
# age      372 non-null float64
# bp       372 non-null float64
# sg       372 non-null float64
# al       372 non-null float64
# su       372 non-null float64
# pc       372 non-null object
# pcc      372 non-null object
# ba       372 non-null object
# bgr      372 non-null float64
# bu       372 non-null float64
# sc       372 non-null float64
# hemo     372 non-null float64
# pcv      372 non-null float64
# htn      372 non-null object
# dm       372 non-null object
# cad      372 non-null object
# appet    372 non-null object
# pe       372 non-null object
# ane      372 non-null object
# dtypes: float64(10), object(9)
# memory usage: 58.1+ KB

# %% [markdown]
# Now, the data are completely clean. We convert attributes `X` and target `y` to numpy arrays and save them to files.

# %%
X = np.array(X)
y = np.array(y)
Xy = np.hstack((X,y[:,np.newaxis]))

np.savetxt('data_cleaned.dat',Xy,fmt='%s')
